# %% [markdown]
# # Battle of neighborhoods week 1 (Data required for the given problem)

# %% [markdown]
# Data
# According to the question, following data are required.
#
# ## 1. Geographic coordinate of Hyderabad cinemas
#
# I need to compare 5 possible locations with current cinemas in Hyderabad. Therefore, I need to find a list of Hyderabad cinema and cinemas' geographic coordinates. I can find the list and coordinates from the google website. The data is downloaded and converted into data frame. The first 5 entries are shown on below table.
#
# Name
#
# Address
#
# Latitude
#
# Longitude
#
# ### 1. Manjeera Mall:
#
# Plot No: S2, Survey No: 1050, JNTU Rd, Phase 3, Kukatpally Housing Board Colony,
# Kukatpally, Hyderabad, Telangana 500072
# 17.4900
# 78.3931
#
# ### 2. Forum Mall
#
# Plot No S-16, Survey No 1009, KPHB Road, K P H B Phase 6, Kukatpally,
# Hyderabad, Telangana 500072
# 17.4843
# 78.3889
#
# ### 3. In orbit mall
#
# Inorbit Mall Rd, Hyderabad, Andhra Pradesh, India	17.4354	78.3827
# Hyderabad central	Hyderabad Central, Punjagutta NO.6-3-673, 674/1,
# G.S.CENTER POINT PUNJAGUTTA CROSS, ROAD, Hyderabad, Telangana 500082
# 17.3850
# 78.4867
#
# ### 4. Imax Hyderabad
#
# IMAX Road Khairtabad Behind of, NTR Marg, Hyderabad, Telangana 500063
# 17.4127
# 78.4658
#
#
# ## 2. Geographic coordinates of 5 possible cinema addresses
#
# Geographic coordinates of 5 possible cinemas are required and I can use Google Map API to find this information.
#
#
# Location, Address, Latitude, Longitude
#
# L1	Gangaram, Chanda Nagar, Hyderabad 500050	17.4939	78.3309
#
#
# L2	Miyapur, Near Miyapur bus stop, Hyderabad 500049	17.5169	78.3428
#
#
# L3	Gachhi bowli, near gachhibowli stadium, Hyderabad- 500031	17.4401	78.3489
#
#
# L4	Patancheru, opposite patancheru bus stand, Hyderabad-500025	17.5287	78.2667
#
#
# L5	Chanda nagar, opposite chanda nagar bus stand, Hyderabad-500023	17.4934	78.3278
#
#
# ## 3. Favourite cinema list of stakeholders
#
# The favorite cinema list of stakeholder is important information that I can use it as profile to select the best location.
#
# Name/Rating
#
#
# Manjeera Mall	4.5
#
#
# Forum Mall	4.5
#
#
# In orbit mall	4.3
#
#
# Hyderabad central	3.4
#
#
# Imax Hyderabad	2.3
#
#
# Talkie town Hyderabad	2.1
#
#
# ## 4. Eating, Shopping and Public transportation facility around cinema
#
# The recommended cinema location needs to have many eating and shopping venues nearby. Convenient public transport is also required. These data can be found by using Four Square API to find these venues around the location. The radius of exploration distance is set to 500 meters, which is about 5 minutes walking distance.
#
# Following type of venue category will be used for the study
# Food, shop and service, bus stop, metro station, night life spot, arts and entertainment
# Let's use Four Square API to query some venues around the first cinema in the cinema list. Only first 5 venues in the category are shown below.
#
# ## Name/Latitude/Longitude/Tips/Users/Visits
#
# •	Metro Station
#
# MTR railway Station 	17.4806	78.4197	0	0	0
#
# Local train station 	17. 23	78.29	0	0	0
#
#
# •	Bus Stop
#
# Miyapur Road / Miyapur Road Bus Stop 	17.1346	78.5638	0	0	0
#
# Kukatpalli Bus Stop	17.4563	78.8745	0	0	0
#
# Green park Road	17.9845	78.8975	0	0	0
#
# Begumpet Bus Stop	17.4637	78.8764	0	0	0
#
# Nature cure Bus Stop	17.4806	78.4197	0	0	0
#
#
# •	Food
#
# Pizza Hut Near By	17.1456	78.5678	0	0	0
#
# Karachi Bakery	17.5657	78.4647	0	0	0
#
# Food panda shop	17.4757	78.4758	0	0	0
#
# Biryanis and more 	17.2829	78.4848	0	0	0
#
# Hyderabad  Dhaba 	17.5859	78.4844	0	0	0
#
#
# •	Arts & Entertainment
#
# Shilpa Ramam 	17.1245	77.3536	0	0	0
#
# Open exhibition arts and science	17.3456	77.4567	0	0	0
#
# Birla arts and science museum	17.3797	77.4476	0	0	0
#
# Annapurna fine arts	17.4675	77.3756	0	0	0
#
# Space fine arts	17.1246	77.3547	0	0	0
